# %% [markdown]
# # Assignment Grades

# %%
# Assinment Average
(1+.85+.85+1)/4*100
# Out:
# 92.5

# %%
# Extra Credit
0.06*(0.85+0.7)*100
# Out:
# 9.299999999999999

# %% [markdown]
# # Gradient Descent Lab - 85%

# %% [markdown]
# Using starting with values from SciPy for gradient descent defeats the point of using gradient descent to understand how to find the values.

# %% [markdown]
# # Gram-Schmidt - 100%

# %% [markdown]
# # Linear Regression - 70%

# %% [markdown]
# You didn't find and import a proper new data set.  You also didn't show how to use linear algrbra to find the coefficients for the exponential model.

# %% [markdown]
# # Try Except Lab - 100%

# %% [markdown]
# # Power Method - 85%

# %% [markdown]
# This is a power method, but it is not what the project asked you to do.  You also have no comments on what you are doing and why in the Jupyter notebook.  You also don't find the propper values since you didn't follow the project.

# %% [markdown]
# # Polynomial Roots - 85%

# %% [markdown]
# Comments were brief but fine

# %%
"
