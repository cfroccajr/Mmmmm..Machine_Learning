# %%
# ================================================================
#   MAT 531 – Multivariable Mathematics for Machine Learning
#   Chapter 5 – Project A
#
#   Title: Power Method for Finding Eigenvalues
#   Student: Nikita S. Karim
#   Instructor Professor Rocca
#   Fall 2025
# ================================================================

import numpy as np
# Matrix A 
A = np.array([
    [6, -4, -8],
    [-3, 10, 11],
    [2, -4, -4]
], dtype=float)

x = np.array([1.0, 0.0, 0.0])

# Power Method iterations
for i in range(20):
    y = A @ x                   # multiply by A
    x = y / np.linalg.norm(y)   # normalize
    lam = x.T @ A @ x          
    print(f"Iter {i}: λ ≈ {lam}, x = {x}")
# Out:
# Iter 0: λ ≈ 6.163265306122449, x = [ 0.85714286 -0.42857143  0.28571429]
# Iter 1: λ ≈ 5.9918200408997935, x = [ 0.72354501 -0.58788032  0.36177251]
# Iter 2: λ ≈ 5.961478163493841, x = [ 0.62854816 -0.67344446  0.38910124]
# Iter 3: λ ≈ 5.970477119767822, x = [ 0.56021713 -0.7252811   0.40015509]
# Iter 4: λ ≈ 5.982731268658596, x = [ 0.51184526 -0.75773171  0.40479266]
# Iter 5: λ ≈ 5.990970192331407, x = [ 0.47828178 -0.77832538  0.40676301]
# Iter 6: λ ≈ 5.995546482622808, x = [ 0.45534045 -0.79153162  0.40760615]
# Iter 7: λ ≈ 5.997877202216568, x = [ 0.43981068 -0.80007981  0.40796919]
# Iter 8: λ ≈ 5.9990095555773655, x = [ 0.4293601  -0.80565671  0.40812641]
# Iter 9: λ ≈ 5.999544342765513, x = [ 0.42235255 -0.80931779  0.40819486]
# Iter 10: λ ≈ 5.9997923781976095, x = [ 0.41766384 -0.81173237  0.40822479]
# Iter 11: λ ≈ 5.999906031394823, x = [ 0.41453081 -0.81333019  0.40823793]
# Iter 12: λ ≈ 5.999957674354589, x = [ 0.41243902 -0.81439003  0.40824371]
# ...

# %%
from numpy import linalg

# %%
np.linalg.matrix_power(A/6,100)
# Out:
# array([[ 0.5, -1. , -1.5],
#        [-1. ,  2. ,  3. ],
#        [ 0.5, -1. , -1.5]])
